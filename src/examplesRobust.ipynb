# %% [markdown]
# <h1><center>Examples</center></h1>

# %%
import networkx as nx
import matplotlib.pyplot as plt
from IPython.display import display
from algorithmRobust import *
from graphs import *
from plot import *
# %matplotlib inline

# %% [markdown]
# ## Complete Graphs

# %%
# Create a complete graph
n = 10
G = create_complete(n)

# Call the algorithm to simplify the graph
qr = 3
G2 = simplify_graph(G, qr, displays=True)

# Draw the graphs and plot
title = f'Complete graph of size {n} with quantifier rank {qr}'
draw_graphs(G, G2, title)
# Out:
# Looking for k=1...
# Removing [(3,), (4,), (5,), (6,), (7,), (8,)] from [(0,), (1,), (2,), (3,), (4,), (5,), (6,), (7,), (8,)]
# Removed 6 vertices

# %% [markdown]
# ## Trees

# %%
# Create a balanced tree
h = 3
G = create_tree(h=h, children=[2,3,4])

# Call the algorithm to simplify the graph
qr = 2
G2 = simplify_graph(G, qr, displays=True)

# Draw the graphs and plot
title = f'Tree of height {h} with quantifier rank {qr}'
draw_graphs(G, G2, title)
# Out:
# Looking for k=1...
# Removing [(11,), (12,)] from [(9,), (10,), (11,), (12,)]
# Removing [(15,), (16,)] from [(13,), (14,), (15,), (16,)]
# Removing [(19,), (20,)] from [(17,), (18,), (19,), (20,)]
# Removing [(23,), (24,)] from [(21,), (22,), (23,), (24,)]
# Removing [(27,), (28,)] from [(25,), (26,), (27,), (28,)]
# Removing [(31,)] from [(29,), (30,), (31,)]
# Looking for k=2...
# Looking for k=3...
# Removing [(5, 17, 18)] from [(3, 9, 10), (4, 14, 13), (5, 17, 18)]
# Removing [(8, 29, 30)] from [(6, 21, 22), (7, 26, 25), (8, 29, 30)]
# Looking for k=4...
# Looking for k=5...
# Removed 17 vertices

# %%
# Create a tree
h = 3
G = create_tree(h=h, children=[3,4,3], rmv=[3,9,24,45])

# Call the algorithm to simplify the graph
qr = 1
G2 = simplify_graph(G, qr, displays=True)

# Draw the graphs and plot
title = f'Tree of height {h} with quantifier rank {qr}'
draw_graphs(G, G2, title)
# Out:
# Looking for k=1...
# Removing [(17,), (18,)] from [(16,), (17,), (18,)]
# Removing [(20,), (21,)] from [(19,), (20,), (21,)]
# Removing [(23,)] from [(22,), (23,)]
# Removing [(26,), (27,)] from [(25,), (26,), (27,)]
# Removing [(29,), (30,)] from [(28,), (29,), (30,)]
# Removing [(35,), (36,)] from [(34,), (35,), (36,)]
# Removing [(38,)] from [(37,), (38,)]
# Looking for k=2...
# Removing [(5, 19), (6, 22), (7, 25)] from [(4, 16), (5, 19), (6, 22), (7, 25)]
# Removing [(10, 34), (11, 37)] from [(8, 28), (10, 34), (11, 37)]
# Looking for k=3...
# Removing [(2, 8, 28)] from [(1, 4, 16), (2, 8, 28)]
# Removed 35 vertices

# %% [markdown]
# ## Random Graphs

# %%
# Create a random graph
n = 10       # Graphs size
p = 0.7      # Probablility of an edge
G = create_random(n, p)

# Call the algorithm to simplify the graph
qr = 1
G2 = simplify_graph(G, qr, displays=True)

# Draw the graphs and plot
title = f'Random graph of size n={n} and probability of having an edge p={p}'
draw_graphs(G, G2, title)
# Out:
# Looking for k=1...
# Looking for k=2...
# Looking for k=3...
# Looking for k=4...
# Removed 0 vertices

# %%
# Create a random graph
n = 10       # Graphs size
p = 0.78      # Probablility of an edge
G = create_random(n, p)

# Call the algorithm to simplify the graph
qr = 2
G2 = simplify_graph(G, qr, displays=True)

# Draw the graphs and plot
title = f'Random graph of size n={n} and probability of having an edge p={p}'
draw_graphs(G, G2, title)
# Out:
# Looking for k=1...
# Looking for k=2...
# Looking for k=3...
# Removed 0 vertices
